# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.DataFrame(pd.read_csv('2D_ABCD29_15_45_65.csv'))


plt.figure(figsize=(12,10))
plt.scatter(data.x, data.y, c=data['T'],s=10)
plt.colorbar()
plt.show()

# %%
import numpy as np

np.random.seed(42)

layers = np.random.randint(low=10,high=100,size=(2,4))
for l in layers:
    A,B,C,D = l
    
    print A,B,C,D
# Out:
# 61 24 81 70
# 30 92 96 84
